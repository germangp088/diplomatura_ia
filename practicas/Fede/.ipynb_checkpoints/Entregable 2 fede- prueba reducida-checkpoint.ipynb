# %%
#Importación de librerías a utilizar 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Creo un dataframe con los datos del excel de la letra
df=pd.read_excel("../smoking_prediction.xlsx")

# %%
#Empiezo la exploración del dataset
df.head(3)
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60   3.377083        0.043056
# 1   1      F   40         160          60   3.375000        0.005556
# 2   2      M   55         170          60   3.333333        0.005556
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0         0.041667       0.041667        0.041667  ...    0.506250
# 1         0.004167       0.041667        0.041667  ...    0.504861
# 2         0.005556       0.041667        0.041667  ...    0.630556
#
#    Urine protein  serum creatinine       AST       ALT       Gtp  oral  \
# 0       0.041667          0.004861  0.750000  0.791667  1.125000     Y
# 1       0.041667          0.004167  0.916667  0.791667  0.750000     Y
# 2       0.041667          0.041667  0.875000  0.666667  0.916667     Y
#
#    dental caries  tartar  smoking
# 0              0       Y        0
# 1              0       Y        0
# 2              0       N        1
#
# [3 rows x 27 columns]

# %%
df.shape
# Out:
# (50000, 27)

# %%
#Vemos que no hay nulos y los tipos de datos que hay en cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   gender               50000 non-null  object
#  2   age                  50000 non-null  int64
#  3   height(cm)           50000 non-null  int64
#  4   weight(kg)           50000 non-null  int64
#  5   waist(cm)            50000 non-null  float64
#  6   eyesight(left)       50000 non-null  float64
#  7   eyesight(right)      50000 non-null  float64
#  8   hearing(left)        50000 non-null  float64
#  9   hearing(right)       50000 non-null  float64
#  10  systolic             50000 non-null  float64
#  11  relaxation           50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  Cholesterol          50000 non-null  float64
#  14  triglyceride         50000 non-null  float64
#  15  HDL                  50000 non-null  float64
#  16  LDL                  50000 non-null  float64
#  17  hemoglobin           50000 non-null  float64
#  18  Urine protein        50000 non-null  float64
#  19  serum creatinine     50000 non-null  float64
#  20  AST                  50000 non-null  float64
#  21  ALT                  50000 non-null  float64
#  22  Gtp                  50000 non-null  float64
#  23  oral                 50000 non-null  object
#  24  dental caries        50000 non-null  int64
#  25  tartar               50000 non-null  object
#  26  smoking              50000 non-null  int64
# dtypes: float64(18), int64(6), object(3)
# memory usage: 10.3+ MB

# %%
#Verificamos nuevamente los nulos
df.isna().sum()/df.shape[0]*100
# Out:
# ID                     0.0
# gender                 0.0
# age                    0.0
# height(cm)             0.0
# weight(kg)             0.0
# waist(cm)              0.0
# eyesight(left)         0.0
# eyesight(right)        0.0
# hearing(left)          0.0
# hearing(right)         0.0
# systolic               0.0
# relaxation             0.0
# fasting blood sugar    0.0
# Cholesterol            0.0
# triglyceride           0.0
# HDL                    0.0
# LDL                    0.0
# hemoglobin             0.0
# Urine protein          0.0
# serum creatinine       0.0
# AST                    0.0
# ALT                    0.0
# Gtp                    0.0
# oral                   0.0
# dental caries          0.0
# tartar                 0.0
# smoking                0.0
# dtype: float64

# %%
df.smoking.value_counts(normalize=True)*100
# Out:
# smoking
# 0    63.342
# 1    36.658
# Name: proportion, dtype: float64

# %%
#Codificación y creación de train y test y dropeo la variable ID ya que no aporta valor predictivo
X = df.drop(["smoking", "ID", "tartar", "Urine protein", "oral", "hearing(left)", "hearing(right)", "dental caries"], axis=1).copy()
y = df.smoking.copy()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
#Voy a hacer uan gráfica para poder representar y entender un poco mejor la composición de fumadores y no fumadores
conteo = df.groupby(['gender', 'smoking']).size().reset_index(name='count')
conteo['smoking'] = conteo['smoking'].map({0: 'No fuma', 1: 'Fuma'})
sns.set(style="whitegrid")
plt.figure(figsize=(8,6))
sns.barplot(data=conteo, x='gender', y='count', hue='smoking', palette='Set2')
plt.title('Comparativa de fumadores por género')
plt.xlabel('Género')
plt.ylabel('Cantidad de personas')
plt.legend(title='¿Fuma?')
plt.tight_layout()
plt.show()

# %%
#Empiezo la depuración en train creando variables dummies de las columnas object
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse_output=False).fit(X_train[["gender"]])

# %%
encoded = ohe.transform((X_train[["gender"]]))

# %%
encoded_df = pd.DataFrame(columns=ohe.get_feature_names_out(), data = encoded, index=X_train.index)

# %%
X_train = pd.concat([X_train, encoded_df], axis="columns")

# %%
X_train = X_train.drop(["gender"], axis=1)

# %%
#Replico el trabajo hecho con las dummies en el test
encoded_test = ohe.transform((X_test[["gender"]]))

# %%
encoded_df_test = pd.DataFrame(columns=ohe.get_feature_names_out(), data = encoded_test, index=X_test.index)

# %%
X_test = pd.concat([X_test, encoded_df_test], axis="columns")

# %%
X_test = X_test.drop(["gender"], axis=1)

# %%
#Chequeo que ahora todas las variables sean compatibles on los árboles
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35000 entries, 8319 to 43737
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  35000 non-null  int64
#  1   height(cm)           35000 non-null  int64
#  2   weight(kg)           35000 non-null  int64
#  3   waist(cm)            35000 non-null  float64
#  4   eyesight(left)       35000 non-null  float64
#  5   eyesight(right)      35000 non-null  float64
#  6   systolic             35000 non-null  float64
#  7   relaxation           35000 non-null  float64
#  8   fasting blood sugar  35000 non-null  float64
#  9   Cholesterol          35000 non-null  float64
#  10  triglyceride         35000 non-null  float64
#  11  HDL                  35000 non-null  float64
#  12  LDL                  35000 non-null  float64
#  13  hemoglobin           35000 non-null  float64
#  14  serum creatinine     35000 non-null  float64
#  15  AST                  35000 non-null  float64
#  16  ALT                  35000 non-null  float64
#  17  Gtp                  35000 non-null  float64
#  18  gender_F             35000 non-null  float64
#  19  gender_M             35000 non-null  float64
# dtypes: float64(17), int64(3)
# memory usage: 5.6 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15000 entries, 28092 to 9154
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  15000 non-null  int64
#  1   height(cm)           15000 non-null  int64
#  2   weight(kg)           15000 non-null  int64
#  3   waist(cm)            15000 non-null  float64
#  4   eyesight(left)       15000 non-null  float64
#  5   eyesight(right)      15000 non-null  float64
#  6   systolic             15000 non-null  float64
#  7   relaxation           15000 non-null  float64
#  8   fasting blood sugar  15000 non-null  float64
#  9   Cholesterol          15000 non-null  float64
#  10  triglyceride         15000 non-null  float64
#  11  HDL                  15000 non-null  float64
#  12  LDL                  15000 non-null  float64
#  13  hemoglobin           15000 non-null  float64
#  14  serum creatinine     15000 non-null  float64
#  15  AST                  15000 non-null  float64
#  16  ALT                  15000 non-null  float64
#  17  Gtp                  15000 non-null  float64
#  18  gender_F             15000 non-null  float64
#  19  gender_M             15000 non-null  float64
# dtypes: float64(17), int64(3)
# memory usage: 2.4 MB

# %%
#Empiezo un featuring selection para un random forest, donde vemosa primera instancia que tartar, Urine protein, hearing y oral_y son las que menos influyen y variables que podríamos dropear de ser necesario.
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
importancias = pd.Series(model.feature_importances_, index=X_train.columns)
importancias.sort_values(ascending=False).plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: >

# %%
#Creo el modelo de random forest con valores de parámetros elegidos a ojo
clf = RandomForestClassifier(n_estimators=390, min_samples_split=20, min_samples_leaf=6, random_state=42)

# %%
#Entreno el modelo
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=6, min_samples_split=20,
#                        n_estimators=390, random_state=42)

# %%
train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print("Train")
print(classification_report(y_train, train_pred))
print("----------------------------------------------------------")
print("Test")
print(classification_report(y_test, test_pred))
# Out:
# Train
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94     22170
#            1       0.88      0.91      0.90     12830
#
#     accuracy                           0.92     35000
#    macro avg       0.91      0.92      0.92     35000
# weighted avg       0.92      0.92      0.92     35000
#
# ----------------------------------------------------------
# Test
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      9501
#            1       0.69      0.74      0.71      5499
#
#     accuracy                           0.78     15000
#    macro avg       0.76      0.77      0.77     15000
# weighted avg       0.78      0.78      0.78     15000

# %%
#Voy a realizar lo mismo con XGBOOST para ver cual de los dos modelos trabaja mejor con mi set de datos

# %%
from xgboost import XGBClassifier

# %%
clf2 = XGBClassifier()

# %%
clf2.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
train_pred2 = clf2.predict(X_train)
test_pred2 = clf2.predict(X_test)

# %%
print("Train")
print(classification_report(y_train, train_pred2))
print("----------------------------------------------------------")
print("Test")
print(classification_report(y_test, test_pred2))
# Out:
# Train
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90     22170
#            1       0.81      0.85      0.83     12830
#
#     accuracy                           0.87     35000
#    macro avg       0.86      0.86      0.86     35000
# weighted avg       0.87      0.87      0.87     35000
#
# ----------------------------------------------------------
# Test
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81      9501
#            1       0.68      0.71      0.69      5499
#
#     accuracy                           0.77     15000
#    macro avg       0.75      0.75      0.75     15000
# weighted avg       0.77      0.77      0.77     15000

# %%
#Voy a probar de nuevo el random forest utilizando la herramienta optuna para modificar los parámetros en una forma más eficiente

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 500),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 2, 100),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 2, 50),
        'max_features': trial.suggest_float('max_features', 0.1, 1.0),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
    }
    model = RandomForestClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy')
    return scores.mean()

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-10-20 00:09:22,882] A new study created in memory with name: no-name-ced49f72-eefc-4fda-829d-b11e285fae86
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-20 00:09:41,131] Trial 0 finished with value: 0.7605713604234755 and parameters: {'n_estimators': 193, 'max_leaf_nodes': 96, 'min_samples_leaf': 37, 'max_features': 0.6387926357773329, 'min_samples_split': 3}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:09:45,427] Trial 1 finished with value: 0.7379428526332473 and parameters: {'n_estimators': 86, 'max_leaf_nodes': 7, 'min_samples_leaf': 44, 'max_features': 0.6410035105688879, 'min_samples_split': 8}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:09:46,377] Trial 2 finished with value: 0.7566571375617378 and parameters: {'n_estimators': 20, 'max_leaf_nodes': 98, 'min_samples_leaf': 42, 'max_features': 0.29110519961044856, 'min_samples_split': 3}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:09:52,447] Trial 3 finished with value: 0.7511999204078482 and parameters: {'n_estimators': 100, 'max_leaf_nodes': 32, 'min_samples_leaf': 27, 'max_features': 0.48875051677790415, 'min_samples_split': 4}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:10:06,276] Trial 4 finished with value: 0.7450570379481162 and parameters: {'n_estimators': 310, 'max_leaf_nodes': 15, 'min_samples_leaf': 16, 'max_features': 0.4297256589643226, 'min_samples_split': 6}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:10:32,774] Trial 5 finished with value: 0.7487999057096323 and parameters: {'n_estimators': 395, 'max_leaf_nodes': 21, 'min_samples_leaf': 27, 'max_features': 0.6331731119758383, 'min_samples_split': 2}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:11:03,219] Trial 6 finished with value: 0.7464284885632301 and parameters: {'n_estimators': 308, 'max_leaf_nodes': 18, 'min_samples_leaf': 5, 'max_features': 0.9539969835279999, 'min_samples_split': 10}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:11:38,069] Trial 7 finished with value: 0.7537142298003849 and parameters: {'n_estimators': 406, 'max_leaf_nodes': 32, 'min_samples_leaf': 6, 'max_features': 0.7158097238609412, 'min_samples_split': 5}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:11:46,455] Trial 8 finished with value: 0.7562856485798135 and parameters: {'n_estimators': 69, 'max_leaf_nodes': 51, 'min_samples_leaf': 3, 'max_features': 0.9183883618709039, 'min_samples_split': 4}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:12:09,792] Trial 9 finished with value: 0.7525142371455744 and parameters: {'n_estimators': 335, 'max_leaf_nodes': 32, 'min_samples_leaf': 27, 'max_features': 0.5920392514089517, 'min_samples_split': 3}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:12:14,487] Trial 10 finished with value: 0.7529713473494694 and parameters: {'n_estimators': 193, 'max_leaf_nodes': 94, 'min_samples_leaf': 36, 'max_features': 0.11616568805333771, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:12:23,532] Trial 11 finished with value: 0.7587713653186358 and parameters: {'n_estimators': 194, 'max_leaf_nodes': 99, 'min_samples_leaf': 49, 'max_features': 0.26184953555663004, 'min_samples_split': 2}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:12:32,137] Trial 12 finished with value: 0.7571428110307523 and parameters: {'n_estimators': 194, 'max_leaf_nodes': 78, 'min_samples_leaf': 49, 'max_features': 0.29376178379307516, 'min_samples_split': 2}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:12:56,485] Trial 13 finished with value: 0.758885679605353 and parameters: {'n_estimators': 213, 'max_leaf_nodes': 70, 'min_samples_leaf': 39, 'max_features': 0.8084995228701395, 'min_samples_split': 2}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:13:23,340] Trial 14 finished with value: 0.7593142191969798 and parameters: {'n_estimators': 246, 'max_leaf_nodes': 70, 'min_samples_leaf': 35, 'max_features': 0.794858487391002, 'min_samples_split': 4}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:14:23,644] Trial 15 finished with value: 0.7596570763403968 and parameters: {'n_estimators': 484, 'max_leaf_nodes': 78, 'min_samples_leaf': 33, 'max_features': 0.8622965110497991, 'min_samples_split': 5}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:15:23,528] Trial 16 finished with value: 0.7599142094017611 and parameters: {'n_estimators': 500, 'max_leaf_nodes': 83, 'min_samples_leaf': 20, 'max_features': 0.8482393148266659, 'min_samples_split': 6}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:16:28,314] Trial 17 finished with value: 0.7574285024591373 and parameters: {'n_estimators': 500, 'max_leaf_nodes': 56, 'min_samples_leaf': 16, 'max_features': 0.9919598236578151, 'min_samples_split': 9}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:16:42,122] Trial 18 finished with value: 0.7601428428732949 and parameters: {'n_estimators': 129, 'max_leaf_nodes': 87, 'min_samples_leaf': 19, 'max_features': 0.720240240686376, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:16:56,009] Trial 19 finished with value: 0.7601427963413531 and parameters: {'n_estimators': 138, 'max_leaf_nodes': 88, 'min_samples_leaf': 21, 'max_features': 0.6962653886352399, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:17:06,263] Trial 20 finished with value: 0.7572571228684201 and parameters: {'n_estimators': 141, 'max_leaf_nodes': 56, 'min_samples_leaf': 11, 'max_features': 0.5341779771674953, 'min_samples_split': 8}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:17:22,026] Trial 21 finished with value: 0.7603714004242921 and parameters: {'n_estimators': 145, 'max_leaf_nodes': 88, 'min_samples_leaf': 21, 'max_features': 0.7140836284402472, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:17:39,200] Trial 22 finished with value: 0.7603713783828457 and parameters: {'n_estimators': 148, 'max_leaf_nodes': 89, 'min_samples_leaf': 21, 'max_features': 0.7535826254269251, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:18:06,509] Trial 23 finished with value: 0.7597427979733998 and parameters: {'n_estimators': 251, 'max_leaf_nodes': 70, 'min_samples_leaf': 32, 'max_features': 0.7515540389978135, 'min_samples_split': 8}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:18:08,517] Trial 24 finished with value: 0.7583428012365134 and parameters: {'n_estimators': 30, 'max_leaf_nodes': 92, 'min_samples_leaf': 23, 'max_features': 0.4343110098831101, 'min_samples_split': 5}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:18:21,046] Trial 25 finished with value: 0.7592285098092247 and parameters: {'n_estimators': 134, 'max_leaf_nodes': 80, 'min_samples_leaf': 12, 'max_features': 0.632343999703348, 'min_samples_split': 9}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:18:34,250] Trial 26 finished with value: 0.7601428502204436 and parameters: {'n_estimators': 162, 'max_leaf_nodes': 100, 'min_samples_leaf': 30, 'max_features': 0.5202197116074502, 'min_samples_split': 6}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:18:42,268] Trial 27 finished with value: 0.7579428249100061 and parameters: {'n_estimators': 68, 'max_leaf_nodes': 60, 'min_samples_leaf': 24, 'max_features': 0.8889411092272578, 'min_samples_split': 7}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:19:04,395] Trial 28 finished with value: 0.7577428183788807 and parameters: {'n_estimators': 228, 'max_leaf_nodes': 64, 'min_samples_leaf': 13, 'max_features': 0.6715973856948664, 'min_samples_split': 6}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:19:11,688] Trial 29 finished with value: 0.7556856461297844 and parameters: {'n_estimators': 94, 'max_leaf_nodes': 43, 'min_samples_leaf': 44, 'max_features': 0.5856362735749464, 'min_samples_split': 9}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:19:44,265] Trial 30 finished with value: 0.7602570640961286 and parameters: {'n_estimators': 276, 'max_leaf_nodes': 89, 'min_samples_leaf': 17, 'max_features': 0.7757402370749262, 'min_samples_split': 8}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:20:03,405] Trial 31 finished with value: 0.7599427702178311 and parameters: {'n_estimators': 163, 'max_leaf_nodes': 88, 'min_samples_leaf': 17, 'max_features': 0.7923045405064062, 'min_samples_split': 8}. Best is trial 0 with value: 0.7605713604234755.
# [I 2025-10-20 00:20:40,587] Trial 32 finished with value: 0.7608285179753356 and parameters: {'n_estimators': 312, 'max_leaf_nodes': 93, 'min_samples_leaf': 22, 'max_features': 0.7601448615259689, 'min_samples_split': 7}. Best is trial 32 with value: 0.7608285179753356.
# [I 2025-10-20 00:21:18,140] Trial 33 finished with value: 0.7609713465461811 and parameters: {'n_estimators': 362, 'max_leaf_nodes': 95, 'min_samples_leaf': 30, 'max_features': 0.6661643926540477, 'min_samples_split': 7}. Best is trial 33 with value: 0.7609713465461811.
# [I 2025-10-20 00:21:52,938] Trial 34 finished with value: 0.7609713808328751 and parameters: {'n_estimators': 364, 'max_leaf_nodes': 95, 'min_samples_leaf': 30, 'max_features': 0.6472718781083533, 'min_samples_split': 6}. Best is trial 34 with value: 0.7609713808328751.
# [I 2025-10-20 00:22:21,398] Trial 35 finished with value: 0.7598856363404435 and parameters: {'n_estimators': 378, 'max_leaf_nodes': 94, 'min_samples_leaf': 39, 'max_features': 0.45915840369579863, 'min_samples_split': 3}. Best is trial 34 with value: 0.7609713808328751.
# [I 2025-10-20 00:22:36,771] Trial 36 finished with value: 0.733685696707556 and parameters: {'n_estimators': 356, 'max_leaf_nodes': 5, 'min_samples_leaf': 30, 'max_features': 0.5890781998418778, 'min_samples_split': 5}. Best is trial 34 with value: 0.7609713808328751.
# [I 2025-10-20 00:23:19,990] Trial 37 finished with value: 0.761228516343289 and parameters: {'n_estimators': 436, 'max_leaf_nodes': 97, 'min_samples_leaf': 28, 'max_features': 0.6420517874448302, 'min_samples_split': 10}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:23:46,956] Trial 38 finished with value: 0.7604571122610967 and parameters: {'n_estimators': 417, 'max_leaf_nodes': 100, 'min_samples_leaf': 25, 'max_features': 0.37518048166388274, 'min_samples_split': 10}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:24:26,631] Trial 39 finished with value: 0.759685681239359 and parameters: {'n_estimators': 434, 'max_leaf_nodes': 75, 'min_samples_leaf': 30, 'max_features': 0.6491748484318104, 'min_samples_split': 9}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:25:05,327] Trial 40 finished with value: 0.7596285155243269 and parameters: {'n_estimators': 448, 'max_leaf_nodes': 84, 'min_samples_leaf': 28, 'max_features': 0.5614790159790163, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:25:33,922] Trial 41 finished with value: 0.7600856771582628 and parameters: {'n_estimators': 301, 'max_leaf_nodes': 95, 'min_samples_leaf': 34, 'max_features': 0.6459398377795091, 'min_samples_split': 10}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:26:07,455] Trial 42 finished with value: 0.7599427873611782 and parameters: {'n_estimators': 347, 'max_leaf_nodes': 95, 'min_samples_leaf': 38, 'max_features': 0.6146049798078472, 'min_samples_split': 3}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:26:45,915] Trial 43 finished with value: 0.7596856445036154 and parameters: {'n_estimators': 377, 'max_leaf_nodes': 95, 'min_samples_leaf': 42, 'max_features': 0.6757773914818869, 'min_samples_split': 4}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:27:28,063] Trial 44 finished with value: 0.7607142502205603 and parameters: {'n_estimators': 331, 'max_leaf_nodes': 100, 'min_samples_leaf': 27, 'max_features': 0.8323645110149741, 'min_samples_split': 8}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:28:10,073] Trial 45 finished with value: 0.7598570730753239 and parameters: {'n_estimators': 326, 'max_leaf_nodes': 83, 'min_samples_leaf': 27, 'max_features': 0.8558546105634519, 'min_samples_split': 8}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:28:51,822] Trial 46 finished with value: 0.7609142371592889 and parameters: {'n_estimators': 286, 'max_leaf_nodes': 100, 'min_samples_leaf': 23, 'max_features': 0.9378706947579948, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:29:31,275] Trial 47 finished with value: 0.7609427955263094 and parameters: {'n_estimators': 283, 'max_leaf_nodes': 92, 'min_samples_leaf': 23, 'max_features': 0.9349069234509005, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:29:55,859] Trial 48 finished with value: 0.7405142175335854 and parameters: {'n_estimators': 276, 'max_leaf_nodes': 11, 'min_samples_leaf': 25, 'max_features': 0.970554714785236, 'min_samples_split': 5}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:30:33,594] Trial 49 finished with value: 0.7594856722591841 and parameters: {'n_estimators': 283, 'max_leaf_nodes': 74, 'min_samples_leaf': 32, 'max_features': 0.9253631964400222, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:31:38,990] Trial 50 finished with value: 0.7596856542998136 and parameters: {'n_estimators': 461, 'max_leaf_nodes': 83, 'min_samples_leaf': 29, 'max_features': 0.9199459098428748, 'min_samples_split': 5}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:32:34,077] Trial 51 finished with value: 0.7603999245046184 and parameters: {'n_estimators': 368, 'max_leaf_nodes': 92, 'min_samples_leaf': 23, 'max_features': 0.996503567688139, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:33:19,762] Trial 52 finished with value: 0.7608856347093763 and parameters: {'n_estimators': 396, 'max_leaf_nodes': 96, 'min_samples_leaf': 23, 'max_features': 0.7461005262942156, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:33:59,151] Trial 53 finished with value: 0.7507999391832417 and parameters: {'n_estimators': 393, 'max_leaf_nodes': 26, 'min_samples_leaf': 19, 'max_features': 0.8815018732858058, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:34:51,959] Trial 54 finished with value: 0.7605999432809917 and parameters: {'n_estimators': 419, 'max_leaf_nodes': 97, 'min_samples_leaf': 25, 'max_features': 0.8284185109405349, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:35:36,974] Trial 55 finished with value: 0.7552285236806414 and parameters: {'n_estimators': 394, 'max_leaf_nodes': 40, 'min_samples_leaf': 32, 'max_features': 0.9484095872318656, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:36:11,962] Trial 56 finished with value: 0.760257095933773 and parameters: {'n_estimators': 468, 'max_leaf_nodes': 91, 'min_samples_leaf': 26, 'max_features': 0.4982641725237969, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:36:50,571] Trial 57 finished with value: 0.759771385729015 and parameters: {'n_estimators': 354, 'max_leaf_nodes': 96, 'min_samples_leaf': 37, 'max_features': 0.7129592449308447, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:37:20,134] Trial 58 finished with value: 0.7603999196065193 and parameters: {'n_estimators': 295, 'max_leaf_nodes': 85, 'min_samples_leaf': 35, 'max_features': 0.6862465995722805, 'min_samples_split': 5}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:37:59,454] Trial 59 finished with value: 0.7596856102169215 and parameters: {'n_estimators': 434, 'max_leaf_nodes': 98, 'min_samples_leaf': 14, 'max_features': 0.5553849941161912, 'min_samples_split': 9}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:38:29,567] Trial 60 finished with value: 0.7599427898102277 and parameters: {'n_estimators': 233, 'max_leaf_nodes': 80, 'min_samples_leaf': 28, 'max_features': 0.8981756017746112, 'min_samples_split': 6}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:39:08,354] Trial 61 finished with value: 0.7608285204243853 and parameters: {'n_estimators': 327, 'max_leaf_nodes': 91, 'min_samples_leaf': 22, 'max_features': 0.7595280596662528, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:39:43,669] Trial 62 finished with value: 0.7609141906273472 and parameters: {'n_estimators': 314, 'max_leaf_nodes': 91, 'min_samples_leaf': 23, 'max_features': 0.7341713907321671, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:40:09,247] Trial 63 finished with value: 0.7598570877696212 and parameters: {'n_estimators': 261, 'max_leaf_nodes': 86, 'min_samples_leaf': 19, 'max_features': 0.6172352372659224, 'min_samples_split': 7}. Best is trial 37 with value: 0.761228516343289.
# [I 2025-10-20 00:40:44,595] Trial 64 finished with value: 0.7614570591999886 and parameters: {'n_estimators': 310, 'max_leaf_nodes': 97, 'min_samples_leaf': 23, 'max_features': 0.7263708235616301, 'min_samples_split': 8}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:41:17,432] Trial 65 finished with value: 0.7608285057300878 and parameters: {'n_estimators': 311, 'max_leaf_nodes': 100, 'min_samples_leaf': 29, 'max_features': 0.658942951527548, 'min_samples_split': 8}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:41:47,240] Trial 66 finished with value: 0.7597713538913705 and parameters: {'n_estimators': 269, 'max_leaf_nodes': 90, 'min_samples_leaf': 31, 'max_features': 0.7153476646290038, 'min_samples_split': 9}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:42:25,280] Trial 67 finished with value: 0.7606856771592424 and parameters: {'n_estimators': 288, 'max_leaf_nodes': 97, 'min_samples_leaf': 24, 'max_features': 0.8110848184723707, 'min_samples_split': 6}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:42:58,478] Trial 68 finished with value: 0.7594285089932015 and parameters: {'n_estimators': 349, 'max_leaf_nodes': 80, 'min_samples_leaf': 20, 'max_features': 0.6042577401928038, 'min_samples_split': 10}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:43:19,727] Trial 69 finished with value: 0.7601713718517203 and parameters: {'n_estimators': 240, 'max_leaf_nodes': 92, 'min_samples_leaf': 26, 'max_features': 0.5756937969236797, 'min_samples_split': 8}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:43:43,414] Trial 70 finished with value: 0.7608570469537613 and parameters: {'n_estimators': 215, 'max_leaf_nodes': 86, 'min_samples_leaf': 17, 'max_features': 0.7314393448626896, 'min_samples_split': 7}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:44:16,399] Trial 71 finished with value: 0.760571375117773 and parameters: {'n_estimators': 317, 'max_leaf_nodes': 98, 'min_samples_leaf': 23, 'max_features': 0.6925141609430318, 'min_samples_split': 7}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:45:01,888] Trial 72 finished with value: 0.760428492667837 and parameters: {'n_estimators': 407, 'max_leaf_nodes': 94, 'min_samples_leaf': 24, 'max_features': 0.7367833819826204, 'min_samples_split': 6}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:45:57,396] Trial 73 finished with value: 0.760399931851767 and parameters: {'n_estimators': 374, 'max_leaf_nodes': 89, 'min_samples_leaf': 21, 'max_features': 0.953805034291102, 'min_samples_split': 8}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:46:37,087] Trial 74 finished with value: 0.7609142151178429 and parameters: {'n_estimators': 335, 'max_leaf_nodes': 97, 'min_samples_leaf': 28, 'max_features': 0.7695600582763461, 'min_samples_split': 6}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:46:44,353] Trial 75 finished with value: 0.7512856371427521 and parameters: {'n_estimators': 301, 'max_leaf_nodes': 93, 'min_samples_leaf': 28, 'max_features': 0.13221263804032468, 'min_samples_split': 5}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:47:23,884] Trial 76 finished with value: 0.760657062464082 and parameters: {'n_estimators': 338, 'max_leaf_nodes': 98, 'min_samples_leaf': 33, 'max_features': 0.7724195787070205, 'min_samples_split': 6}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:48:06,642] Trial 77 finished with value: 0.7604284730754406 and parameters: {'n_estimators': 365, 'max_leaf_nodes': 88, 'min_samples_leaf': 8, 'max_features': 0.7988628131694475, 'min_samples_split': 6}. Best is trial 64 with value: 0.7614570591999886.
# [I 2025-10-20 00:48:32,025] Trial 78 finished with value: 0.7617427922622161 and parameters: {'n_estimators': 258, 'max_leaf_nodes': 100, 'min_samples_leaf': 26, 'max_features': 0.626730206846482, 'min_samples_split': 6}. Best is trial 78 with value: 0.7617427922622161.
# [I 2025-10-20 00:48:57,113] Trial 79 finished with value: 0.761714226548047 and parameters: {'n_estimators': 253, 'max_leaf_nodes': 100, 'min_samples_leaf': 26, 'max_features': 0.6458520762984484, 'min_samples_split': 5}. Best is trial 78 with value: 0.7617427922622161.
# [I 2025-10-20 00:49:18,528] Trial 80 finished with value: 0.7619427816499945 and parameters: {'n_estimators': 217, 'max_leaf_nodes': 100, 'min_samples_leaf': 26, 'max_features': 0.6355666854849408, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:49:40,485] Trial 81 finished with value: 0.7605999702205368 and parameters: {'n_estimators': 254, 'max_leaf_nodes': 100, 'min_samples_leaf': 26, 'max_features': 0.5324886696021744, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:50:00,558] Trial 82 finished with value: 0.7605427604226125 and parameters: {'n_estimators': 204, 'max_leaf_nodes': 95, 'min_samples_leaf': 31, 'max_features': 0.619493787917569, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:50:24,476] Trial 83 finished with value: 0.7607428134856796 and parameters: {'n_estimators': 226, 'max_leaf_nodes': 94, 'min_samples_leaf': 29, 'max_features': 0.6618896378317205, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:50:50,369] Trial 84 finished with value: 0.761542778383942 and parameters: {'n_estimators': 260, 'max_leaf_nodes': 100, 'min_samples_leaf': 27, 'max_features': 0.6419760031797953, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:51:14,106] Trial 85 finished with value: 0.759685681239359 and parameters: {'n_estimators': 263, 'max_leaf_nodes': 97, 'min_samples_leaf': 25, 'max_features': 0.5705581809775483, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:51:32,799] Trial 86 finished with value: 0.7611713677716039 and parameters: {'n_estimators': 183, 'max_leaf_nodes': 100, 'min_samples_leaf': 30, 'max_features': 0.6352208702928721, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:51:49,052] Trial 87 finished with value: 0.7605714045063677 and parameters: {'n_estimators': 165, 'max_leaf_nodes': 100, 'min_samples_leaf': 34, 'max_features': 0.6410496336249524, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:52:06,793] Trial 88 finished with value: 0.7602570616470791 and parameters: {'n_estimators': 183, 'max_leaf_nodes': 94, 'min_samples_leaf': 31, 'max_features': 0.6005757276397453, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:52:23,219] Trial 89 finished with value: 0.7560285204165482 and parameters: {'n_estimators': 184, 'max_leaf_nodes': 49, 'min_samples_leaf': 27, 'max_features': 0.6950632513334104, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:52:43,892] Trial 90 finished with value: 0.7608285204243853 and parameters: {'n_estimators': 216, 'max_leaf_nodes': 98, 'min_samples_leaf': 29, 'max_features': 0.6306527430590084, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:53:09,871] Trial 91 finished with value: 0.7597713710347175 and parameters: {'n_estimators': 253, 'max_leaf_nodes': 92, 'min_samples_leaf': 26, 'max_features': 0.6694342597812212, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:53:31,290] Trial 92 finished with value: 0.7604285343016798 and parameters: {'n_estimators': 242, 'max_leaf_nodes': 96, 'min_samples_leaf': 30, 'max_features': 0.5900104845746456, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:53:53,516] Trial 93 finished with value: 0.7596856616469624 and parameters: {'n_estimators': 276, 'max_leaf_nodes': 90, 'min_samples_leaf': 27, 'max_features': 0.5407448213819167, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:54:05,070] Trial 94 finished with value: 0.7599428143007234 and parameters: {'n_estimators': 119, 'max_leaf_nodes': 100, 'min_samples_leaf': 32, 'max_features': 0.6399845296242365, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:54:25,308] Trial 95 finished with value: 0.7600856722601635 and parameters: {'n_estimators': 198, 'max_leaf_nodes': 93, 'min_samples_leaf': 25, 'max_features': 0.6794243362603088, 'min_samples_split': 5}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:54:49,515] Trial 96 finished with value: 0.760914197974496 and parameters: {'n_estimators': 236, 'max_leaf_nodes': 96, 'min_samples_leaf': 28, 'max_features': 0.653042531652809, 'min_samples_split': 10}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:55:02,786] Trial 97 finished with value: 0.7595999938930499 and parameters: {'n_estimators': 176, 'max_leaf_nodes': 89, 'min_samples_leaf': 22, 'max_features': 0.48608249112099683, 'min_samples_split': 6}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:55:27,079] Trial 98 finished with value: 0.7597713710347175 and parameters: {'n_estimators': 221, 'max_leaf_nodes': 98, 'min_samples_leaf': 34, 'max_features': 0.7047224251223225, 'min_samples_split': 6}. Best is trial 80 with value: 0.7619427816499945.
# [I 2025-10-20 00:55:50,774] Trial 99 finished with value: 0.7595713914431373 and parameters: {'n_estimators': 295, 'max_leaf_nodes': 87, 'min_samples_leaf': 30, 'max_features': 0.5103019527516679, 'min_samples_split': 4}. Best is trial 80 with value: 0.7619427816499945.

# %%
#Voy a correr con los parametros recomendados por el optuna
best_params = {'n_estimators': 217, 'max_leaf_nodes': 100, 'min_samples_leaf': 26, 'max_features': 0.6355666854849408, 'min_samples_split': 5}
final_model = RandomForestClassifier(**best_params, random_state=42)
final_model.fit(X_train, y_train)
train_pred3 = final_model.predict(X_train)
test_pred3 = final_model.predict(X_test)
print("Train")
print(classification_report(y_train, train_pred3))
print("----------------------------------------------------------")
print("Test")
print(classification_report(y_test, test_pred3))
# Out:
# Train
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83     22170
#            1       0.69      0.76      0.73     12830
#
#     accuracy                           0.79     35000
#    macro avg       0.77      0.78      0.78     35000
# weighted avg       0.79      0.79      0.79     35000
#
# ----------------------------------------------------------
# Test
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81      9501
#            1       0.66      0.72      0.69      5499
#
#     accuracy                           0.76     15000
#    macro avg       0.74      0.75      0.75     15000
# weighted avg       0.77      0.76      0.76     15000
