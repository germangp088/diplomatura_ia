# %%
# CONFIGURACIÓN E IMPORTACIONES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import math
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer # <--- CORRECCIÓN: Usamos Porter (clásico)
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Descargar recursos necesarios de NLTK
nltk.download('stopwords')
nltk.download('punkt')

# Configuración de gráficos
sns.set_style("whitegrid")
# %matplotlib inline

# %%
# CARGA DE DATOS

# Nombres de columnas según la documentación de S
cols = ['target', 'ids', 'date', 'flag', 'user', 'text']


# 1. Cargar Dataset de ENTRENAMIENTO (El grande de 1.6M)
df_train = pd.read_csv('training.1600000.processed.noemoticon para IA.csv', 
                       encoding='latin-1', header=None, names=cols, sep=';')

# 2. Cargar Dataset de TEST
df_test = pd.read_csv('testdata.manual.2009.06.14.csv', 
                      encoding='latin-1', header=None, names=cols)

# --- FILTRADO DE CLASES ---
# Eliminamos la clase 2 (Neutro) para hacer clasificación binaria (Positivo vs Negativo)
# 0 = Negativo, 4 = Positivo
df_train = df_train[df_train['target'] != 2]
df_test = df_test[df_test['target'] != 2]

# --- OPCIONAL: MUESTREO (Descomentar si tu PC va muy lento) ---
# df_train = df_train.sample(n=100000, random_state=42) 

print(f"Datos de Entrenamiento: {df_train.shape}")
print(f"Datos de Prueba: {df_test.shape}")
print("Distribución en Train:\n", df_train['target'].value_counts())
